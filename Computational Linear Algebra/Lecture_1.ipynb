# %%
import numpy as np

# %% [markdown]
# ## Exercise - 1

# %%
a = np.array([
    [0.85,0.1, 0.05, 0.0],
])
b = np.array([
    [0.90, 0.07, 0.02, 0.01],
    [0.0, 0.93, 0.05, 0.02],
    [0.0, 0.0, 0.85, 0.15],
    [0.0, 0.0, 0.0, 1.0],
])

# %%
np.dot(a, b)
# Out:
# array([[0.765 , 0.1525, 0.0645, 0.018 ]])

# %% [markdown]
# ## Exercise - 2

# %%
people = np.array([
    [6, 5, 3, 1],
    [3, 6, 2, 2],
    [3, 4, 3, 1]
])
shops = np.array([
    [1.50, 1.00],
    [2.00, 2.50],
    [5.00, 4.50],
    [16.00, 17.00]
])

# %%
np.dot(people, shops)
# Out:
# array([[50. , 49. ],
#        [58.5, 61. ],
#        [43.5, 43.5]])
